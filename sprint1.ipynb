# %%
import pandas as pd

df=pd.DataFrame({"Chips":["Simba","Lays","Doritos","Crack-a-Snack","Nik Naks","Flyers"],
                "Stock Price":[14,13,18,0.50,1,1],
                "Selling Price":[19,17,23,1,2,2],
                "Quantity":[20,50,150,20,54,45],
                "Drinks":["Coke","Twizza","Red Bull","Score","Jive","Sparletta"],
                "Stock Price1":[14,7,10,7,8,8],
                "Selling Price1":[22,12,18,11,13,14],
                 "Quantity1":[2,5,15,2,5,4],
                "Chocolates":["Cadberry","PS","Kit Kat","Bar One","Oreo","Lunch Bar"],
                "Stock Price2":[14,13,18,0.50,1,1],
                "Selling Price2":[19,17,23,1,2,2],
                 "Quantity2":[20,50,150,20,54,45],
                "Fruits":["Apple","Grapes","Peach","Guava","Water Melon","Kiwi"],
                "Stock Price3":[14,13,18,0.50,1,1],
                "Selling Price3":[19,17,23,1,2,2],
                 "Quantity3":[20,50,150,20,54,45],
                "Pies":["Pepper-Steak","Steak and kidney","Steak","Sauage","Chicken","Mushroom"],
                "Stock Price4":[14,13,18,0.50,1,1],
                "Selling Price4":[19,17,23,1,2,2],
                 "Quantity4":[20,50,150,20,54,45],
                "Cupcakes":["Vannila","Chocolate","Bran","Mint","Choc-Mint","Cappuccino"],
                "Stock Price5":[14,13,18,0.50,1,1],
                "Selling Price5":[19,17,23,1,2,2],
                 "Quantity5":[20,50,150,20,54,45],
                "Veggies":["Cabbage","Carrot","Potatoes","Onion","Spinach","Brocolli"],
                "Stock Price6":[14,13,18,0.50,1,1],
                "Selling Price6":[19,17,23,1,2,2],
                "Quantity6":[20,50,150,20,54,45]},columns=["Chips","Stock Price","Selling Price","Quantity","Drinks","Stock Price1","Selling Price1","Quantity1","Chocolates","Stock Price2","Selling Price2","Quantity2","Fruits","Stock Price3","Selling Price3","Quantity3","Pies","Stock Price4","Selling Price4","Quantity4","Cupcakes","Selling Price5","Stock Price5","Quantity5","Veggies","Selling Price6","Stock Price6","Quantity6"],index=["a","b","c","d","e","f"])
df.rename(columns={"Stock Price1": "Stock Price", "Selling Price1": "Selling Price", "Quantity1": "Quantity",
                  "Stock Price2": "Stock Price", "Selling Price2": "Selling Price", "Quantity2": "Quantity",
                  "Stock Price3": "Stock Price", "Selling Price3": "Selling Price", "Quantity3": "Quantity",
                  "Stock Price4": "Stock Price", "Selling Price4": "Selling Price", "Quantity4": "Quantity",
                  "Stock Price5": "Stock Price", "Selling Price5": "Selling Price", "Quantity5": "Quantity",
                  "Stock Price6": "Stock Price", "Selling Price6": "Selling Price", "Quantity6": "Quantity"},inplace = True)
df
# Out:
#            Chips  Stock Price  Selling Price  Quantity     Drinks  \
# a          Simba         14.0             19        20       Coke
# b           Lays         13.0             17        50     Twizza
# c        Doritos         18.0             23       150   Red Bull
# d  Crack-a-Snack          0.5              1        20      Score
# e       Nik Naks          1.0              2        54       Jive
# f         Flyers          1.0              2        45  Sparletta
#
#    Stock Price  Selling Price  Quantity Chocolates  Stock Price  ...  \
# a           14             22         2   Cadberry         14.0  ...
# b            7             12         5         PS         13.0  ...
# c           10             18        15    Kit Kat         18.0  ...
# d            7             11         2    Bar One          0.5  ...
# e            8             13         5       Oreo          1.0  ...
# f            8             14         4  Lunch Bar          1.0  ...
#
# ...

# %%
df.head()
# Out:
#            Chips  Stock Price  Selling Price Quantity    Drinks  Stock Price  \
# a          Simba         14.0             19       20      Coke         14.0
# b           Lays         13.0             17       50    Twizza         13.0
# c        Doritos         18.0             23      150  Red Bull         18.0
# d  Crack-a-Snack          0.5              1       20     Score          0.5
# e       Nik Naks          1.0              2       54      Jive          1.0
#
#    Selling Price Quantity Chocolates  Stock Price  ...  Selling Price  \
# a             19       20   Cadberry         14.0  ...             19
# b             17       50         PS         13.0  ...             17
# c             23      150    Kit Kat         18.0  ...             23
# d              1       20    Bar One          0.5  ...              1
# e              2       54       Oreo          1.0  ...              2
#
#   Quantity   Cupcakes  Selling Price  Stock Price Quantity   Veggies  \
# ...

# %%
df.tail()
# Out:
#            Chips  Stock Price  Selling Price Quantity     Drinks  Stock Price  \
# b           Lays         13.0             17       50     Twizza         13.0
# c        Doritos         18.0             23      150   Red Bull         18.0
# d  Crack-a-Snack          0.5              1       20      Score          0.5
# e       Nik Naks          1.0              2       54       Jive          1.0
# f         Flyers          1.0              2       45  Sparletta          1.0
#
#    Selling Price Quantity Chocolates  Stock Price  ...  Selling Price  \
# b             17       50         PS         13.0  ...             17
# c             23      150    Kit Kat         18.0  ...             23
# d              1       20    Bar One          0.5  ...              1
# e              2       54       Oreo          1.0  ...              2
# f              2       45  Lunch Bar          1.0  ...              2
#
#   Quantity    Cupcakes  Selling Price  Stock Price Quantity   Veggies  \
# ...

# %%
df.describe()
# Out:
#        Stock Price  Selling Price   Quantity  Stock Price  Selling Price  \
# count     6.000000       6.000000    6.00000     6.000000       6.000000
# mean      7.916667      10.666667   56.50000     7.916667      10.666667
# std       7.939878      10.053192   48.14042     7.939878      10.053192
# min       0.500000       1.000000   20.00000     0.500000       1.000000
# 25%       1.000000       2.000000   26.25000     1.000000       2.000000
# 50%       7.000000       9.500000   47.50000     7.000000       9.500000
# 75%      13.750000      18.500000   53.00000    13.750000      18.500000
# max      18.000000      23.000000  150.00000    18.000000      23.000000
#
#         Quantity  Stock Price  Selling Price   Quantity  Stock Price  \
# count    6.00000     6.000000       6.000000    6.00000     6.000000
# mean    56.50000     7.916667      10.666667   56.50000     7.916667
# std     48.14042     7.939878      10.053192   48.14042     7.939878
# ...

# %%
print(df.plot(kind='bar',x='Fruits',y='Selling Price'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
